# %%
lista_completa = [[('João', 'J720'), ('Maria', 'M205'), ('José', 'J371'), ('Cláudia', 'C546'), ('Ana', 'A347')],
                  [[8.0, 9.0, 10.0], [9.0, 7.0, 6.0], [3.4, 7.0, 7.0], [5.5, 6.6, 8.0], [6.0, 10.0, 9.5]],
                  [9.0, 7.3, 5.8, 6.7, 8.5],
                  ['Aprovado', 'Aprovado', 'Reprovado', 'Aprovado', 'Aprovado']]

# %%
coluna = ["Notas", "Media Final", "Situacao"]
cadastro = {coluna[i]: lista_completa[i+1] for i in range(len(coluna))}
cadastro
# Out:
# {'Notas': [[8.0, 9.0, 10.0],
#   [9.0, 7.0, 6.0],
#   [3.4, 7.0, 7.0],
#   [5.5, 6.6, 8.0],
#   [6.0, 10.0, 9.5]],
#  'Media Final': [9.0, 7.3, 5.8, 6.7, 8.5],
#  'Situacao': ['Aprovado', 'Aprovado', 'Reprovado', 'Aprovado', 'Aprovado']}

# %%
cadastro["Estudante"] = [lista_completa[0][i][0] for i in range(len(lista_completa[0]))]
cadastro
# Out:
# {'Notas': [[8.0, 9.0, 10.0],
#   [9.0, 7.0, 6.0],
#   [3.4, 7.0, 7.0],
#   [5.5, 6.6, 8.0],
#   [6.0, 10.0, 9.5]],
#  'Media Final': [9.0, 7.3, 5.8, 6.7, 8.5],
#  'Situacao': ['Aprovado', 'Aprovado', 'Reprovado', 'Aprovado', 'Aprovado'],
#  'Estudante': ['João', 'Maria', 'José', 'Cláudia', 'Ana']}

# %%
nomes_estudantes = [ "Enrico Monteiro", "Luna Pereira", "Anthony Silveira", "Letícia Fernandes",
                    "João Vitor Nascimento", "Maysa Caldeira", "Diana Carvalho", "Mariane da Rosa",
                    "Camila Fernandes", "Levi Alves", "Nicolas da Rocha", "Amanda Novaes",
                    "Laís Moraes", "Letícia Oliveira", "Lucca Novaes", "Lara Cunha",
                    "Beatriz Martins", "João Vitor Azevedo", "Stephany Rosa", "Gustavo Henrique Lima" ]

medias_estudantes = [5.4, 4.1, 9.1, 5.3, 6.9, 3.1, 10.0, 5.0, 8.2, 5.5,
                    8.1, 7.4, 5.0, 3.7, 8.1, 6.2, 6.1, 5.6, 6.7, 8.2]

# %%
notas = {nomes: medias for nomes, medias in zip(nomes_estudantes, medias_estudantes) if medias >= 9.0}
notas
# Out:
# {'Anthony Silveira': 9.1, 'Diana Carvalho': 10.0}

# %%
lista_de_listas = [[4,6,5,9], [1,0,7,2], [3,4,1,8]]
soma = 0

for i in lista_de_listas:
  soma += sum(i)

soma
# Out:
# 50

# %%
lista_de_tuplas = [('Pedro', 1.74, 81), ('Júlia', 1.65, 67), ('Otávio', 1.81, 83)]
armazena = []

for i in range(len(lista_de_tuplas)):
  armazena.append(lista_de_tuplas[i][2])

armazena
# Out:
# [81, 67, 83]

# %%
lista = ['Pedro', 'Júlia', 'Otávio', 'Eduardo']

tupla = []

for i in range(len(lista)):
  tupla += (i, lista[i])

tupla
# Out:
# [0, 'Pedro', 1, 'Júlia', 2, 'Otávio', 3, 'Eduardo']

# %%
lista = ['Pedro', 'Júlia', 'Otávio', 'Eduardo']

tupla = []

for i in range(len(lista)):
  # Sempre lembrar de abrir um parenteses a mais para gerar uma tupla "(())"
  tupla.append((i, lista[i]))

tupla
# Out:
# [(0, 'Pedro'), (1, 'Júlia'), (2, 'Otávio'), (3, 'Eduardo')]

# %%
aluguel = [('Apartamento', 1700), ('Apartamento', 1400), ('Casa', 2150), ('Apartamento', 1900), ('Casa', 1100)]

somente_ap = [ap[1] for ap in aluguel if ap[0] == "Apartamento"]
somente_ap
# Out:
# [1700, 1400, 1900]

# %%
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
despesa = [860, 490, 1010, 780, 900, 630, 590, 770, 620, 560, 840, 360]

dict_lista = {x: y for x, y in zip(meses, despesa)}
dict_lista
# Out:
# {'Jan': 860,
#  'Fev': 490,
#  'Mar': 1010,
#  'Abr': 780,
#  'Mai': 900,
#  'Jun': 630,
#  'Jul': 590,
#  'Ago': 770,
#  'Set': 620,
#  'Out': 560,
#  'Nov': 840,
#  'Dez': 360}

# %%
vendas = [('2023', 4093), ('2021', 4320), ('2021', 5959), ('2022', 8883), ('2023', 9859), ('2022', 5141), ('2022', 7688), ('2022', 9544), ('2023', 4794), ('2021', 7178), ('2022', 3030), ('2021', 7471), ('2022', 4226), ('2022', 8190), ('2021', 9680), ('2022', 5616)]

vendas_2022 = (ano_venda[1] for ano_venda in vendas if ano_venda[0] == '2022' and ano_venda[1] >= 6000)
list(vendas_2022)
# Out:
# [8883, 7688, 9544, 8190]

# %%
notas = {'João': [8.0, 9.0, 10.0], 'Maria': [9.0, 7.0, 6.0], 'José': [3.4, 7.0, 8.0],'Cláudia': [5.5, 6.6, 8.0], 'Ana': [6.0, 10.0, 9.5], 'Joaquim': [5.5, 7.5, 9.0], 'Júlia': [6.0, 8.0, 7.0], 'Pedro': [3.0, 4.0, 6.0]}

try:
  nome = input("Digite o nome do aluno: ")
  resultado = notas[nome]
except KeyError:
  print("Estudante não matriculado na turma")
else:
  print(resultado)
finally:
  print("A consulta foi finalizada")
# Out:
# Digite o nome do aluno: 3
# Estudante não matriculado na turma
# A consulta foi finalizada

# %%
def media(lista:list=[0]) -> float:
  calculo = sum(lista)/len(lista)
  if len(lista) > 4:
     raise ValueError("A lista não pode pussuir mais de 4 notas")
  return calculo

# %%
try:
  notas = [8, 7, 9, 4, 6]
  resultado = media(notas)
except TypeError:
    print("Não foi possível calcular a média")
except ValueError as e:
  print(e)
else:
    print(resultado)
finally:
    print("A consulta foi finalizada")
# Out:
# A lista não pode pussuir mais de 4 notas
# A consulta foi finalizada

# %%
def media(lista:list=[0]) -> float:
  calculo = sum(lista)/len(lista)
  if len(lista) > 4:
    raise ValueError("Não pode haver mais de 4 notas")
  return calculo

notas = []

for i in range(5):
  notas.append(float(input("Digite a nota: ")))
# Out:
# Digite a nota: 8
# Digite a nota: 9
# Digite a nota: 5
# Digite a nota: 72
# Digite a nota: 4

# %%
try:
  resultado = media(notas)
except TypeError:
  print("Não foi possível calcular a média")
except ValueError as e:
  print(e)
else:
  resultado
finally:
  "Média calculada"
# Out:
# Não pode haver mais de 4 notas

# %%
def exibir_notas_anual(lista):
  if len(lista) > 3:
    raise ValueError("A lista deve conter até 3 notas")

  for i, nota in enumerate(lista):
    print(f"{i+1}º Trimestre = {nota}")

try:
  notas = [5.0, 2.0, 6.0, 8.0]
  exibir_notas_anual(notas)
except Exception as e:
  print(type(e), f'Erro: {e}')
# Out:
# <class 'ValueError'> Erro: A lista deve conter até 3 notas

# %%
pNum = float(input("Digite o primeiro número: "))
sNum = float(input("Digite o segundo número: "))

try:
  divisao = pNum/sNum
except:
  print("impossível dividir por zero")
else:
  print("A divisão foi realizada com sucesso")
finally:
  print("Programa finalizado")
# Out:
# Digite o primeiro número: 0
# Digite o segundo número: 0
# impossível dividir por zero
# Programa finalizado

# %%
idades = {'Júlia': 16, 'Carol': 23, 'Alberto': 19, 'Roberta': 17}

try:
  chave = input()
  valor = idades[chave]
except KeyError:
  print("Chave não encontrada")
else:
  print(valor)
# Out:
# Júlia
# 16

# %%
lista = [1, 2, 3]
def converte_lista(lista):
  try:
     lista_float = [float(numeros) for numeros in lista]
  except Exception as e:
    print(type(e), f'Erro: {e}')
  else:
    return lista_float
  finally:
    print("Fim da execução")

# %%
converte_lista(lista)
# Out:
# Fim da execução
# [1.0, 2.0, 3.0]

# %%
lista1 = [4,6,7,9,10]
lista2 = [-4,6,8,7,9]

def soma_listas(lista1, lista2):
  try:
    if len(lista1) == len(lista2):
      dados = [(lista1[i], lista2[i], lista1[i]+lista2[i]) for i in range(len(lista1))]
    else:
      raise IndexError('A quantidade de elementos é diferente')
  except Exception as e:
    print(type(e), f'Erro: {e}')
  else:
    return dados

soma_listas(lista1,lista2)
soma_listas
# Out:
# <function __main__.soma_listas(lista1, lista2)>

# %%
def <nome_funcao>(<parametro1>,<parametro2>):
  try:
      if: <parametro1> = <parametro2>: variable = <parametro1> + <parametro2>

  return

# %%
gabarito = ['D', 'A', 'B', 'C', 'A']

# Criando a função que recebe a lista de listas com as notas dos estudantes
def corretor(testes: list):
  pontuacoes = [] # criando a lista que receberá as pontuações caso a exceção não seja lançada
  try:
    for teste in testes:
      nota = 0 # variável que acumula a nota de cada estudante
      for i in range(len(teste)):
        if teste[i] not in ['A', 'B', 'C', 'D']: # Verificamos se temos uma alternativa valida
          raise ValueError(f'A alternativa {teste[i]} não é uma opção de alternativa válida')
        elif teste[i] == gabarito[i]: # Verificamos se as respostas são iguais e adicionamos à nota
          nota += 1
      pontuacoes.append(nota) # adicionamos a nota do(a) estudante na lista de pontuações
  except Exception as e:
    print(e)
  else:
    return pontuacoes # retornando a lista de pontuações se não lançarmos a exceção

# %%
regra = []

def nome_funcao(parametro1lista:list) -> int:
  resultado = []
  try:
    for valores in parametro1lista:
      somatorio = 0
      for i in range(len(valores)):
        if valores[i] not in regra:
          raise ValueError(f'O valor {valores[i]} não faz parte da regra')
        elif valores[i] == regra[i]:
          somatorio += 1
          resultado.append(somatorio)
  except Exception as e:
    print(e)
  else:
    return resultado

# %%
# Testando no exemplo que não lança exceção
testes_sem_ex = [['D', 'A', 'B', 'C', 'A'], ['C', 'A', 'A', 'C', 'A'], ['D', 'B', 'A', 'C', 'A']]
acertos(testes_sem_ex)
# Out:
# A alternativa D é inválida

# %%
pontuacoes = [',', '.', '!', '?']

def corretor (texto:list):
  for palavras in texto:
    if ',' in palavras or '.' in palavras or '!' in palavras or '?' in palavras:
      raise ValueError(f'A letra "{palavras}" contém pontuacoes')
  return "Texto tratado!"

lista_tratada = ['Python', 'é', 'uma', 'linguagem', 'de', 'programação', 'poderosa', 'versátil',
                  'e', 'fácil', 'de', 'aprender', 'utilizada', 'em', 'diversos', 'campos', 'desde',
                  'análise', 'de', 'dados', 'até', 'inteligência', 'artificial']

try:
  avalia_letras = corretor(lista_tratada)
except Exception as e:
  print(e)
else:
  print(avalia_letras)

lista_nao_tratada = ['Python', 'é', 'uma', 'linguagem', 'de', 'programação', 'poderosa,', 'versátil',
                  'e', 'fácil,', 'de', 'aprender', 'utilizada', 'em', 'diversos', 'campos,', 'desde',
                  'análise', 'de', 'dados', 'até', 'inteligência', 'artificial!']
try:
  avalia_letras = corretor(lista_nao_tratada)
except Exception as e:
  print(e)
else:
  print(avalia_letras)
# Out:
# Texto tratado!
# A letra "poderosa," contém pontuacoes

# %%
def divide_colunas(pressao:list, temperatura:list) -> list:
  razao = []
  try:
    if len(pressao) != len(temperatura):
      raise ValueError (f'A pressão e temperatura contém listas de diferentes tamanhos')
    resultado = [round(a / b, 2) for a, b in zip(pressao,temperatura)]
  except ValueError as e:
    print(e)
  except ZeroDivisionError as e:
    print(f'{e}: o valor não pode ser 0')
  else:
    return resultado

  # Testando no exemplo que não lança exceção
pressoes = [100, 120, 140, 160, 180]
temperaturas = [20, 25, 30, 35, 40]

divide_colunas(pressoes, temperaturas)

# Testando no exemplo que lança exceção (ZeroDivisionError)
pressoes2 = [60, 120, 140, 160, 180]
temperaturas2 = [0, 25, 30, 35, 40]

divide_colunas(pressoes2, temperaturas2)

# Testando no exemplo que lança exceção (ValueError)
pressoes3 = [100, 120, 140, 160]
temperaturas3 = [20, 25, 30, 35, 40]

divide_colunas(pressoes3, temperaturas3)
# Out:
# division by zero: o valor não pode ser 0
# A pressão e temperatura contém listas de diferentes tamanhos

# %%
import numpy as np
a = np.array([[1, 2], [3, 4]])
b = np.array([10, 20])
a + b
# Out:
# array([[11, 22],
#        [13, 24]])
